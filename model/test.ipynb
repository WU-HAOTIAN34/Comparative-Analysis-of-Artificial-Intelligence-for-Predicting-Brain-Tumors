# %%
from keras.layers import Input, Conv2D, BatchNormalization, ReLU, MaxPooling2D, Concatenate, GlobalMaxPooling2D, Dropout, Dense, Lambda, Reshape, Activation, Multiply, Add
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.layers import Input, Dropout, Dense, GlobalAveragePooling2D
from keras.models import Sequential, Model
from keras import backend as K
from tensorflow import keras
import tensorflow as tf
import numpy as np
import sys
sys.path.append("/root/autodl-tmp/training_tool/")
from training_tool import load_data, draw_curve, draw_matrix, TimeHistory

# %%
labels = ['glioma', 'meningioma', 'pituitary']
data_path = '/root/autodl-tmp/dataset/figshare_MBTD/augmented'
image_size = 200
x_train, x_test, y_train, y_test = load_data(data_path, labels, image_size)
# Out:
# 100%|██████████| 3420/3420 [00:11<00:00, 305.03it/s]
# 100%|██████████| 286/286 [00:01<00:00, 254.86it/s]
# 100%|██████████| 3396/3396 [00:11<00:00, 298.05it/s]
# 100%|██████████| 142/142 [00:00<00:00, 259.21it/s]
# 100%|██████████| 3720/3720 [00:16<00:00, 228.76it/s]
# 100%|██████████| 186/186 [00:00<00:00, 191.91it/s]
# (614, 200, 200, 3)
# (10536, 200, 200, 3)
# (614, 3)
# (10536, 3)

# %%
def block(inputs, filters):

    m = Conv2D(filters, 1, padding='same')(inputs)
    m = BatchNormalization()(m)
    m = ReLU()(m)

    a = Conv2D(filters, 3, padding='same')(inputs)
    a = BatchNormalization()(a)
    a = ReLU()(a)
    
    b = Concatenate()([m, a])

    d = Conv2D(filters * 2, 3, padding='same')(b)
    d = BatchNormalization()(d)
    d = ReLU()(d)

    d = Conv2D(filters * 2, 3, padding='same')(d)
    d = BatchNormalization()(d)
    d = ReLU()(d)
    
    x = Concatenate()([b, d])

    m = Conv2D(filters*4, 1, padding='same')(inputs)
    m = BatchNormalization()(m)
    m = ReLU()(m)
    
    x = Add()([m, x])

    y = Conv2D(filters*2, 1)(x)
    y = BatchNormalization()(y)
    y = ReLU()(y)
    
    return y


def channel_attention(inputs, reduction=8):
    shape = K.int_shape(inputs)
    x = MaxPooling2D(pool_size=(shape[1], shape[2]))(inputs)
    x = Conv2D(shape[3] // reduction, 1, padding='same', kernel_initializer='he_normal', use_bias=False)(x)
    x = Activation('relu')(x)
    x = Conv2D(shape[3], 1, padding='same', kernel_initializer='he_normal', use_bias=False)(x)
    x = Activation('sigmoid')(x)
    x = Multiply()([x, inputs])
    
    return x

def new_attention(inputs):

    b, h, w, c = inputs.shape.as_list()

    x = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True))(inputs)
    y = Lambda(lambda x: K.max(x, axis=-1, keepdims=True))(inputs)

    x = tf.reshape(x, [-1, 1, h*w])
    y = tf.reshape(y, [-1, 1, h*w])

    x = K.batch_dot(x, tf.reshape(inputs, [-1, h*w, c]))
    y = K.batch_dot(y, tf.reshape(inputs, [-1, h*w, c]))

    x = tf.reshape(x, [-1, 1, 1, c])
    y = tf.reshape(y, [-1, 1, 1, c])

    z = Multiply()([x, y])
    x = Activation('sigmoid')(z)

    y = channel_attention(inputs)
    x = Add()([x, y])
    
    x = Multiply()([x, inputs])

    return x


def load_model():
    
    K.clear_session()
    inputs = Input(shape=(image_size, image_size, 3))
    
    x = Conv2D(32, 3, padding='same')(inputs)
    x = BatchNormalization()(x)
    y = ReLU()(x)

    x = MaxPooling2D()(y)
    x = Conv2D(64, 3, padding='same')(x)
    x = BatchNormalization()(x)
    z = ReLU()(x)

    x = MaxPooling2D()(z)
    x = Concatenate()([ Conv2D(32, 5, strides=4, padding='same')(y), x])
    k = block(x, 64)

    x = MaxPooling2D()(k)
    x = Concatenate()([ Conv2D(32, 9, strides=8, padding='same')(y), Conv2D(64, 5, strides=4, padding='same')(z),  x])
    j = block(x, 128)
    
    x = MaxPooling2D()(j)
    x = Concatenate()([ Conv2D(64, 9, strides=8, padding='valid')(z), Conv2D(128, 5, strides=4, padding='valid')(k),  x])
    x = block(x, 256)
    
    x = new_attention(x)
    
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    x = Dense(3, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=x)
    
    return model

# %%
model = load_model()
adam = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 200, 200, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 200, 200, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 200, 200, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 100, 100, 32  0           ['re_lu[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 100, 100, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 100, 100, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 100, 100, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 50, 50, 32)   25632       ['re_lu[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 64)  0           ['re_lu_1[0][0]']
#
#  concatenate (Concatenate)      (None, 50, 50, 96)   0           ['conv2d_2[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 50, 50, 64)   6208        ['concatenate[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 50, 50, 64)   55360       ['concatenate[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 50, 50, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 50, 50, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 50, 50, 64)   0           ['batch_normalization_2[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 50, 50, 64)   0           ['batch_normalization_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 50, 50, 128)  0           ['re_lu_2[0][0]',
#                                                                   're_lu_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 50, 50, 128)  147584      ['concatenate_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 50, 50, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 50, 50, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 50, 50, 128)  147584      ['re_lu_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 50, 50, 256)  24832       ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 50, 50, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 50, 50, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 50, 50, 128)  0           ['batch_normalization_5[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 50, 50, 256)  0           ['batch_normalization_6[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 50, 50, 256)  0           ['concatenate_1[0][0]',
#                                                                   're_lu_5[0][0]']
#
#  add (Add)                      (None, 50, 50, 256)  0           ['re_lu_6[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 50, 50, 128)  32896       ['add[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 50, 50, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 50, 50, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 32)   82976       ['re_lu[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 64)   102464      ['re_lu_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 128)  0          ['re_lu_7[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 25, 25, 224)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 128)  28800       ['concatenate_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 128)  258176      ['concatenate_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 25, 25, 128)  512        ['conv2d_11[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 25, 25, 128)  512        ['conv2d_12[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 25, 25, 128)  0           ['batch_normalization_8[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 25, 25, 128)  0           ['batch_normalization_9[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 25, 25, 256)  0           ['re_lu_8[0][0]',
#                                                                   're_lu_9[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 25, 25, 256)  590080      ['concatenate_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 25, 25, 256)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 25, 25, 256)  590080      ['re_lu_10[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 25, 25, 512)  115200      ['concatenate_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 25, 25, 256)  0           ['batch_normalization_11[0][0]']
#
#  re_lu_12 (ReLU)                (None, 25, 25, 512)  0           ['batch_normalization_12[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 25, 25, 512)  0           ['concatenate_4[0][0]',
#                                                                   're_lu_11[0][0]']
#
#  add_1 (Add)                    (None, 25, 25, 512)  0           ['re_lu_12[0][0]',
#                                                                   'concatenate_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 25, 25, 256)  131328      ['add_1[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 25, 25, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 12, 12, 64)   331840      ['re_lu_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 12, 12, 128)  409728      ['re_lu_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 256)  0          ['re_lu_13[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 12, 12, 448)  0           ['conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 12, 12, 256)  114944      ['concatenate_6[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 12, 12, 256)  1032448     ['concatenate_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 12, 12, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 12, 12, 256)  0           ['batch_normalization_14[0][0]']
#
#  re_lu_15 (ReLU)                (None, 12, 12, 256)  0           ['batch_normalization_15[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 12, 12, 512)  0           ['re_lu_14[0][0]',
#                                                                   're_lu_15[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 12, 12, 512)  2359808     ['concatenate_7[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 12, 12, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 12, 12, 512)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 12, 12, 512)  2359808     ['re_lu_16[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 12, 12, 1024  459776      ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 12, 12, 512)  2048       ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 12, 12, 1024  4096       ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  re_lu_17 (ReLU)                (None, 12, 12, 512)  0           ['batch_normalization_17[0][0]']
#
#  re_lu_18 (ReLU)                (None, 12, 12, 1024  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 12, 12, 1024  0           ['concatenate_7[0][0]',
#                                 )                                 're_lu_17[0][0]']
#
#  add_2 (Add)                    (None, 12, 12, 1024  0           ['re_lu_18[0][0]',
#                                 )                                 'concatenate_8[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 12, 12, 512)  524800      ['add_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 12, 12, 512)  2048       ['conv2d_24[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 12, 12, 512)  0           ['batch_normalization_19[0][0]']
#
#  lambda (Lambda)                (None, 12, 12, 1)    0           ['re_lu_19[0][0]']
#
#  lambda_1 (Lambda)              (None, 12, 12, 1)    0           ['re_lu_19[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 1, 1, 512)   0           ['re_lu_19[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 1, 144)       0           ['lambda[0][0]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 144, 512)     0           ['re_lu_19[0][0]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 1, 144)       0           ['lambda_1[0][0]']
#
#  tf.reshape_3 (TFOpLambda)      (None, 144, 512)     0           ['re_lu_19[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 1, 1, 64)     32768       ['max_pooling2d_4[0][0]']
#
#  tf.linalg.matmul (TFOpLambda)  (None, 1, 512)       0           ['tf.reshape[0][0]',
#                                                                   'tf.reshape_2[0][0]']
#
#  tf.linalg.matmul_1 (TFOpLambda  (None, 1, 512)      0           ['tf.reshape_1[0][0]',
#  )                                                                'tf.reshape_3[0][0]']
#
#  activation_1 (Activation)      (None, 1, 1, 64)     0           ['conv2d_25[0][0]']
#
#  tf.reshape_4 (TFOpLambda)      (None, 1, 1, 512)    0           ['tf.linalg.matmul[0][0]']
#
#  tf.reshape_5 (TFOpLambda)      (None, 1, 1, 512)    0           ['tf.linalg.matmul_1[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 1, 1, 512)    32768       ['activation_1[0][0]']
#
#  multiply (Multiply)            (None, 1, 1, 512)    0           ['tf.reshape_4[0][0]',
#                                                                   'tf.reshape_5[0][0]']
#
#  activation_2 (Activation)      (None, 1, 1, 512)    0           ['conv2d_26[0][0]']
#
#  activation (Activation)        (None, 1, 1, 512)    0           ['multiply[0][0]']
#
#  multiply_1 (Multiply)          (None, 12, 12, 512)  0           ['activation_2[0][0]',
#                                                                   're_lu_19[0][0]']
#
#  add_3 (Add)                    (None, 12, 12, 512)  0           ['activation[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  multiply_2 (Multiply)          (None, 12, 12, 512)  0           ['add_3[0][0]',
#                                                                   're_lu_19[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['multiply_2[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 512)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 3)            1539        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 10,040,707
# Trainable params: 10,029,763
# Non-trainable params: 10,944
# __________________________________________________________________________________________________

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint(filepath='model-test.h5',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 5, min_delta = 0.001,
                              mode='auto',verbose=1)
time_callback = TimeHistory()
history = model.fit(x_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=36,
                   callbacks=[tensorboard,checkpoint,reduce_lr, time_callback])
# Out:
# Epoch 1/50
#   6/264 [..............................] - ETA: 12s - loss: 1.2224 - accuracy: 0.4815WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0254s vs `on_train_batch_end` time: 0.0274s). Check your callbacks.
# 263/264 [============================>.] - ETA: 0s - loss: 0.5956 - accuracy: 0.7630
# Epoch 1: val_accuracy improved from -inf to 0.33491, saving model to model-test.h5
# Epoch 1: 15.80 seconds
# 264/264 [==============================] - 16s 53ms/step - loss: 0.5953 - accuracy: 0.7631 - val_loss: 3.9858 - val_accuracy: 0.3349 - lr: 1.0000e-04
# Epoch 2/50
# 264/264 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8798
# Epoch 2: val_accuracy improved from 0.33491 to 0.36338, saving model to model-test.h5
# Epoch 2: 13.49 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.3069 - accuracy: 0.8798 - val_loss: 8.3812 - val_accuracy: 0.3634 - lr: 1.0000e-04
# Epoch 3/50
# 264/264 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9279
# Epoch 3: val_accuracy improved from 0.36338 to 0.92979, saving model to model-test.h5
# Epoch 3: 13.53 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.1934 - accuracy: 0.9279 - val_loss: 0.1862 - val_accuracy: 0.9298 - lr: 1.0000e-04
# Epoch 4/50
# 264/264 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9494
# Epoch 4: val_accuracy did not improve from 0.92979
# Epoch 4: 13.30 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.1356 - accuracy: 0.9494 - val_loss: 0.5688 - val_accuracy: 0.8046 - lr: 1.0000e-04
# Epoch 5/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9683
# Epoch 5: val_accuracy did not improve from 0.92979
# Epoch 5: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0880 - accuracy: 0.9683 - val_loss: 0.3748 - val_accuracy: 0.8653 - lr: 1.0000e-04
# Epoch 6/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0791 - accuracy: 0.9728
# Epoch 6: val_accuracy did not improve from 0.92979
# Epoch 6: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0797 - accuracy: 0.9726 - val_loss: 0.9951 - val_accuracy: 0.7894 - lr: 1.0000e-04
# Epoch 7/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9892
# Epoch 7: val_accuracy did not improve from 0.92979
# Epoch 7: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0338 - accuracy: 0.9892 - val_loss: 0.7276 - val_accuracy: 0.8359 - lr: 1.0000e-04
# Epoch 8/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9908
# Epoch 8: val_accuracy did not improve from 0.92979
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# Epoch 8: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0292 - accuracy: 0.9908 - val_loss: 0.2639 - val_accuracy: 0.9070 - lr: 1.0000e-04
# Epoch 9/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9981
# Epoch 9: val_accuracy improved from 0.92979 to 0.96679, saving model to model-test.h5
# Epoch 9: 13.49 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.0956 - val_accuracy: 0.9668 - lr: 3.0000e-05
# Epoch 10/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9985
# Epoch 10: val_accuracy did not improve from 0.96679
# Epoch 10: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.1110 - val_accuracy: 0.9630 - lr: 3.0000e-05
# Epoch 11/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9989
# Epoch 11: val_accuracy did not improve from 0.96679
# Epoch 11: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.0947 - val_accuracy: 0.9649 - lr: 3.0000e-05
# Epoch 12/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9993
# Epoch 12: val_accuracy did not improve from 0.96679
# Epoch 12: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.1321 - val_accuracy: 0.9583 - lr: 3.0000e-05
# Epoch 13/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9986
# Epoch 13: val_accuracy improved from 0.96679 to 0.97818, saving model to model-test.h5
# Epoch 13: 13.52 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.0641 - val_accuracy: 0.9782 - lr: 3.0000e-05
# Epoch 14/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9992
# Epoch 14: val_accuracy did not improve from 0.97818
# Epoch 14: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.1052 - val_accuracy: 0.9630 - lr: 3.0000e-05
# Epoch 15/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9997
# Epoch 15: val_accuracy did not improve from 0.97818
# Epoch 15: 13.27 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.1107 - val_accuracy: 0.9668 - lr: 3.0000e-05
# Epoch 16/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9986
# Epoch 16: val_accuracy did not improve from 0.97818
# Epoch 16: 13.24 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.1361 - val_accuracy: 0.9620 - lr: 3.0000e-05
# Epoch 17/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9984
# Epoch 17: val_accuracy did not improve from 0.97818
# Epoch 17: 13.29 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.1598 - val_accuracy: 0.9469 - lr: 3.0000e-05
# Epoch 18/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9963
# Epoch 18: val_accuracy did not improve from 0.97818
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# Epoch 18: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.2983 - val_accuracy: 0.9175 - lr: 3.0000e-05
# Epoch 19/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 19: val_accuracy did not improve from 0.97818
# Epoch 19: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0709 - val_accuracy: 0.9744 - lr: 9.0000e-06
# Epoch 20/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9997
# Epoch 20: val_accuracy did not improve from 0.97818
# Epoch 20: 13.25 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9744 - lr: 9.0000e-06
# Epoch 21/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 21: val_accuracy did not improve from 0.97818
# Epoch 21: 13.22 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0790 - val_accuracy: 0.9715 - lr: 9.0000e-06
# Epoch 22/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.7435e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.97818
# Epoch 22: 13.20 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 7.7363e-04 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9753 - lr: 9.0000e-06
# Epoch 23/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.0847e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.97818
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# Epoch 23: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 7.1150e-04 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9744 - lr: 9.0000e-06
# Epoch 24/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 24: val_accuracy did not improve from 0.97818
# Epoch 24: 13.32 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0686 - val_accuracy: 0.9734 - lr: 2.7000e-06
# Epoch 25/50
# 264/264 [==============================] - ETA: 0s - loss: 8.3820e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.97818
# Epoch 25: 13.25 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 8.3820e-04 - accuracy: 1.0000 - val_loss: 0.0826 - val_accuracy: 0.9763 - lr: 2.7000e-06
# Epoch 26/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.9088e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.97818
# Epoch 26: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 7.9388e-04 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9753 - lr: 2.7000e-06
# Epoch 27/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 27: val_accuracy did not improve from 0.97818
# Epoch 27: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0679 - val_accuracy: 0.9772 - lr: 2.7000e-06
# Epoch 28/50
# 264/264 [==============================] - ETA: 0s - loss: 6.0622e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.97818
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# Epoch 28: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.0622e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9782 - lr: 2.7000e-06
# Epoch 29/50
# 264/264 [==============================] - ETA: 0s - loss: 7.3983e-04 - accuracy: 0.9999
# Epoch 29: val_accuracy did not improve from 0.97818
# Epoch 29: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.3983e-04 - accuracy: 0.9999 - val_loss: 0.0611 - val_accuracy: 0.9763 - lr: 8.1000e-07
# Epoch 30/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.9431e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.97818
# Epoch 30: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.9672e-04 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9763 - lr: 8.1000e-07
# Epoch 31/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 31: val_accuracy did not improve from 0.97818
# Epoch 31: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0672 - val_accuracy: 0.9782 - lr: 8.1000e-07
# Epoch 32/50
# 264/264 [==============================] - ETA: 0s - loss: 4.5026e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.97818
# Epoch 32: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 4.5026e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9772 - lr: 8.1000e-07
# Epoch 33/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.5360e-04 - accuracy: 0.9998
# Epoch 33: val_accuracy did not improve from 0.97818
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# Epoch 33: 13.25 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 7.5345e-04 - accuracy: 0.9998 - val_loss: 0.0624 - val_accuracy: 0.9744 - lr: 8.1000e-07
# Epoch 34/50
# 264/264 [==============================] - ETA: 0s - loss: 8.2658e-04 - accuracy: 0.9997
# Epoch 34: val_accuracy did not improve from 0.97818
# Epoch 34: 13.33 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 8.2658e-04 - accuracy: 0.9997 - val_loss: 0.0644 - val_accuracy: 0.9753 - lr: 2.4300e-07
# Epoch 35/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.7974e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.97818
# Epoch 35: 13.20 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 5.8454e-04 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9763 - lr: 2.4300e-07
# Epoch 36/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.0999e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.97818
# Epoch 36: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 5.1150e-04 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9763 - lr: 2.4300e-07
# Epoch 37/50
# 263/264 [============================>.] - ETA: 0s - loss: 4.0567e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.97818
# Epoch 37: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 4.0675e-04 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9763 - lr: 2.4300e-07
# Epoch 38/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.3356e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.97818
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
# Epoch 38: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.3468e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9772 - lr: 2.4300e-07
# Epoch 39/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.9302e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.97818
# Epoch 39: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.9300e-04 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9772 - lr: 7.2900e-08
# Epoch 40/50
# 264/264 [==============================] - ETA: 0s - loss: 5.1303e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.97818
# Epoch 40: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.1303e-04 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9753 - lr: 7.2900e-08
# Epoch 41/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.7421e-04 - accuracy: 0.9999
# Epoch 41: val_accuracy did not improve from 0.97818
# Epoch 41: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.7328e-04 - accuracy: 0.9999 - val_loss: 0.0637 - val_accuracy: 0.9753 - lr: 7.2900e-08
# Epoch 42/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.8863e-04 - accuracy: 0.9999
# Epoch 42: val_accuracy did not improve from 0.97818
# Epoch 42: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.8812e-04 - accuracy: 0.9999 - val_loss: 0.0640 - val_accuracy: 0.9772 - lr: 7.2900e-08
# Epoch 43/50
# 264/264 [==============================] - ETA: 0s - loss: 5.5358e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.97818
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 2.1869998079182552e-08.
# Epoch 43: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.5358e-04 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9763 - lr: 7.2900e-08
# Epoch 44/50
# 264/264 [==============================] - ETA: 0s - loss: 3.9667e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.97818
# Epoch 44: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 3.9667e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9763 - lr: 2.1870e-08
# Epoch 45/50
# 264/264 [==============================] - ETA: 0s - loss: 6.5126e-04 - accuracy: 0.9999
# Epoch 45: val_accuracy did not improve from 0.97818
# Epoch 45: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.5126e-04 - accuracy: 0.9999 - val_loss: 0.0646 - val_accuracy: 0.9772 - lr: 2.1870e-08
# Epoch 46/50
# 263/264 [============================>.] - ETA: 0s - loss: 8.9030e-04 - accuracy: 0.9999
# Epoch 46: val_accuracy did not improve from 0.97818
# Epoch 46: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 8.8904e-04 - accuracy: 0.9999 - val_loss: 0.0634 - val_accuracy: 0.9772 - lr: 2.1870e-08
# Epoch 47/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.1710e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.97818
# Epoch 47: 13.32 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 6.1642e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9763 - lr: 2.1870e-08
# Epoch 48/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.3488e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.97818
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.560999210591944e-09.
# Epoch 48: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.5802e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9772 - lr: 2.1870e-08
# Epoch 49/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.2818e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.97818
# Epoch 49: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.2742e-04 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9763 - lr: 6.5610e-09
# Epoch 50/50
# 264/264 [==============================] - ETA: 0s - loss: 8.1044e-04 - accuracy: 0.9998
# Epoch 50: val_accuracy did not improve from 0.97818
# Epoch 50: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 8.1044e-04 - accuracy: 0.9998 - val_loss: 0.0637 - val_accuracy: 0.9763 - lr: 6.5610e-09
# Total training time: 669.40 seconds

# %%
draw_curve(history)

# %%
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
loss,acc = model.evaluate(x_test,y_test,verbose = 1)
draw_matrix(labels, y_test_new, pred, acc)
# Out:
# 20/20 [==============================] - 1s 13ms/step
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0888 - accuracy: 0.9707
# Test Accuracy:  97.07
#               precision    recall  f1-score   support
#
#       glioma     0.9759    0.9895    0.9826       286
#   meningioma     0.9493    0.9225    0.9357       142
#    pituitary     0.9785    0.9785    0.9785       186
#
#     accuracy                         0.9707       614
#    macro avg     0.9679    0.9635    0.9656       614
# weighted avg     0.9705    0.9707    0.9705       614

# %%
# %reset -f

# %%
labels = ['glioma', 'meningioma', 'pituitary']
data_path = '/root/autodl-tmp/dataset/figshare_MBTD/augmented'
image_size = 200
x_train, x_test, y_train, y_test = load_data(data_path, labels, image_size)


model = load_model()
adam = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint(filepath='model-test.h5',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 5, min_delta = 0.001,
                              mode='auto',verbose=1)
time_callback = TimeHistory()
history = model.fit(x_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=36,
                   callbacks=[tensorboard,checkpoint,reduce_lr, time_callback])


draw_curve(history)
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
loss,acc = model.evaluate(x_test,y_test,verbose = 1)
draw_matrix(labels, y_test_new, pred, acc)
# %reset -f
# Out:
# 100%|██████████| 3420/3420 [00:11<00:00, 306.58it/s]
# 100%|██████████| 286/286 [00:01<00:00, 254.64it/s]
# 100%|██████████| 3396/3396 [00:11<00:00, 295.70it/s]
# 100%|██████████| 142/142 [00:00<00:00, 245.47it/s]
# 100%|██████████| 3720/3720 [00:16<00:00, 228.58it/s]
# 100%|██████████| 186/186 [00:00<00:00, 192.56it/s]
# (614, 200, 200, 3)
# (10536, 200, 200, 3)
# (614, 3)
# (10536, 3)
# Epoch 1/50
#   5/264 [..............................] - ETA: 12s - loss: 1.2774 - accuracy: 0.4667 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0257s vs `on_train_batch_end` time: 0.0404s). Check your callbacks.
# 264/264 [==============================] - ETA: 0s - loss: 0.6323 - accuracy: 0.7504
# Epoch 1: val_accuracy improved from -inf to 0.34725, saving model to model-test.h5
# Epoch 1: 16.65 seconds
# 264/264 [==============================] - 17s 54ms/step - loss: 0.6323 - accuracy: 0.7504 - val_loss: 6.1336 - val_accuracy: 0.3472 - lr: 1.0000e-04
# Epoch 2/50
# 264/264 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.8752
# Epoch 2: val_accuracy improved from 0.34725 to 0.47913, saving model to model-test.h5
# Epoch 2: 13.52 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.3268 - accuracy: 0.8752 - val_loss: 5.0979 - val_accuracy: 0.4791 - lr: 1.0000e-04
# Epoch 3/50
# 264/264 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9193
# Epoch 3: val_accuracy improved from 0.47913 to 0.86622, saving model to model-test.h5
# Epoch 3: 13.53 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.2138 - accuracy: 0.9193 - val_loss: 0.3403 - val_accuracy: 0.8662 - lr: 1.0000e-04
# Epoch 4/50
# 264/264 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9481
# Epoch 4: val_accuracy did not improve from 0.86622
# Epoch 4: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.1347 - accuracy: 0.9481 - val_loss: 4.4877 - val_accuracy: 0.3880 - lr: 1.0000e-04
# Epoch 5/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9658
# Epoch 5: val_accuracy did not improve from 0.86622
# Epoch 5: 13.28 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0920 - accuracy: 0.9658 - val_loss: 0.6202 - val_accuracy: 0.8178 - lr: 1.0000e-04
# Epoch 6/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0722 - accuracy: 0.9757
# Epoch 6: val_accuracy did not improve from 0.86622
# Epoch 6: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0727 - accuracy: 0.9755 - val_loss: 0.7540 - val_accuracy: 0.8150 - lr: 1.0000e-04
# Epoch 7/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9843
# Epoch 7: val_accuracy did not improve from 0.86622
# Epoch 7: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0471 - accuracy: 0.9843 - val_loss: 0.9547 - val_accuracy: 0.7989 - lr: 1.0000e-04
# Epoch 8/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0542 - accuracy: 0.9810
# Epoch 8: val_accuracy did not improve from 0.86622
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# Epoch 8: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0545 - accuracy: 0.9808 - val_loss: 0.5579 - val_accuracy: 0.8501 - lr: 1.0000e-04
# Epoch 9/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0157 - accuracy: 0.9948
# Epoch 9: val_accuracy improved from 0.86622 to 0.96964, saving model to model-test.h5
# Epoch 9: 13.58 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.0875 - val_accuracy: 0.9696 - lr: 3.0000e-05
# Epoch 10/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9983
# Epoch 10: val_accuracy improved from 0.96964 to 0.97723, saving model to model-test.h5
# Epoch 10: 13.53 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.0683 - val_accuracy: 0.9772 - lr: 3.0000e-05
# Epoch 11/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9986
# Epoch 11: val_accuracy improved from 0.97723 to 0.97818, saving model to model-test.h5
# Epoch 11: 13.44 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 0.0689 - val_accuracy: 0.9782 - lr: 3.0000e-05
# Epoch 12/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9996
# Epoch 12: val_accuracy did not improve from 0.97818
# Epoch 12: 13.22 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.1506 - val_accuracy: 0.9478 - lr: 3.0000e-05
# Epoch 13/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9989
# Epoch 13: val_accuracy did not improve from 0.97818
# Epoch 13: 13.17 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0885 - val_accuracy: 0.9715 - lr: 3.0000e-05
# Epoch 14/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9997
# Epoch 14: val_accuracy did not improve from 0.97818
# Epoch 14: 13.22 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0650 - val_accuracy: 0.9772 - lr: 3.0000e-05
# Epoch 15/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992
# Epoch 15: val_accuracy did not improve from 0.97818
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# Epoch 15: 13.33 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.3193 - val_accuracy: 0.9127 - lr: 3.0000e-05
# Epoch 16/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9995
# Epoch 16: val_accuracy did not improve from 0.97818
# Epoch 16: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.0585 - val_accuracy: 0.9772 - lr: 9.0000e-06
# Epoch 17/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 17: val_accuracy improved from 0.97818 to 0.98008, saving model to model-test.h5
# Epoch 17: 13.59 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0634 - val_accuracy: 0.9801 - lr: 9.0000e-06
# Epoch 18/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9993
# Epoch 18: val_accuracy did not improve from 0.98008
# Epoch 18: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0674 - val_accuracy: 0.9753 - lr: 9.0000e-06
# Epoch 19/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.98008
# Epoch 19: 13.41 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 0.9772 - lr: 9.0000e-06
# Epoch 20/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 20: val_accuracy did not improve from 0.98008
# Epoch 20: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0677 - val_accuracy: 0.9782 - lr: 9.0000e-06
# Epoch 21/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 21: val_accuracy did not improve from 0.98008
# Epoch 21: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0723 - val_accuracy: 0.9791 - lr: 9.0000e-06
# Epoch 22/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 22: val_accuracy did not improve from 0.98008
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# Epoch 22: 13.39 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0676 - val_accuracy: 0.9744 - lr: 9.0000e-06
# Epoch 23/50
# 264/264 [==============================] - ETA: 0s - loss: 7.8460e-04 - accuracy: 0.9999
# Epoch 23: val_accuracy did not improve from 0.98008
# Epoch 23: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.8460e-04 - accuracy: 0.9999 - val_loss: 0.0642 - val_accuracy: 0.9772 - lr: 2.7000e-06
# Epoch 24/50
# 264/264 [==============================] - ETA: 0s - loss: 7.3530e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.98008
# Epoch 24: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.3530e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9763 - lr: 2.7000e-06
# Epoch 25/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.7691e-04 - accuracy: 0.9999
# Epoch 25: val_accuracy did not improve from 0.98008
# Epoch 25: 13.27 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 6.7717e-04 - accuracy: 0.9999 - val_loss: 0.0598 - val_accuracy: 0.9763 - lr: 2.7000e-06
# Epoch 26/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 26: val_accuracy did not improve from 0.98008
# Epoch 26: 13.33 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0857 - val_accuracy: 0.9715 - lr: 2.7000e-06
# Epoch 27/50
# 264/264 [==============================] - ETA: 0s - loss: 5.9110e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.98008
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# Epoch 27: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.9110e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9782 - lr: 2.7000e-06
# Epoch 28/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.9892e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.98008
# Epoch 28: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.9810e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9763 - lr: 8.1000e-07
# Epoch 29/50
# 263/264 [============================>.] - ETA: 0s - loss: 4.1653e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.98008
# Epoch 29: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 4.1634e-04 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9772 - lr: 8.1000e-07
# Epoch 30/50
# 264/264 [==============================] - ETA: 0s - loss: 7.1013e-04 - accuracy: 0.9999
# Epoch 30: val_accuracy did not improve from 0.98008
# Epoch 30: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.1013e-04 - accuracy: 0.9999 - val_loss: 0.0647 - val_accuracy: 0.9763 - lr: 8.1000e-07
# Epoch 31/50
# 264/264 [==============================] - ETA: 0s - loss: 5.0036e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.98008
# Epoch 31: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.0036e-04 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9763 - lr: 8.1000e-07
# Epoch 32/50
# 264/264 [==============================] - ETA: 0s - loss: 6.8766e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.98008
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# Epoch 32: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.8766e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9763 - lr: 8.1000e-07
# Epoch 33/50
# 264/264 [==============================] - ETA: 0s - loss: 5.3303e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.98008
# Epoch 33: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.3303e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9782 - lr: 2.4300e-07
# Epoch 34/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.7898e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.98008
# Epoch 34: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.1502e-04 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9763 - lr: 2.4300e-07
# Epoch 35/50
# 263/264 [============================>.] - ETA: 0s - loss: 3.3818e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.98008
# Epoch 35: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 3.3784e-04 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9782 - lr: 2.4300e-07
# Epoch 36/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.2674e-04 - accuracy: 0.9999
# Epoch 36: val_accuracy did not improve from 0.98008
# Epoch 36: 13.33 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 6.2628e-04 - accuracy: 0.9999 - val_loss: 0.0616 - val_accuracy: 0.9772 - lr: 2.4300e-07
# Epoch 37/50
# 263/264 [============================>.] - ETA: 0s - loss: 4.9902e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.98008
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
# Epoch 37: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 4.9834e-04 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9772 - lr: 2.4300e-07
# Epoch 38/50
# 264/264 [==============================] - ETA: 0s - loss: 6.1081e-04 - accuracy: 0.9999
# Epoch 38: val_accuracy did not improve from 0.98008
# Epoch 38: 13.39 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.1081e-04 - accuracy: 0.9999 - val_loss: 0.0608 - val_accuracy: 0.9782 - lr: 7.2900e-08
# Epoch 39/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.7039e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.98008
# Epoch 39: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.7478e-04 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9782 - lr: 7.2900e-08
# Epoch 40/50
# 264/264 [==============================] - ETA: 0s - loss: 3.8155e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.98008
# Epoch 40: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 3.8155e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9782 - lr: 7.2900e-08
# Epoch 41/50
# 264/264 [==============================] - ETA: 0s - loss: 7.3135e-04 - accuracy: 0.9999
# Epoch 41: val_accuracy did not improve from 0.98008
# Epoch 41: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.3135e-04 - accuracy: 0.9999 - val_loss: 0.0613 - val_accuracy: 0.9772 - lr: 7.2900e-08
# Epoch 42/50
# 264/264 [==============================] - ETA: 0s - loss: 8.5545e-04 - accuracy: 0.9999
# Epoch 42: val_accuracy did not improve from 0.98008
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.1869998079182552e-08.
# Epoch 42: 13.39 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 8.5545e-04 - accuracy: 0.9999 - val_loss: 0.0613 - val_accuracy: 0.9791 - lr: 7.2900e-08
# Epoch 43/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.6575e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.98008
# Epoch 43: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.6486e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9782 - lr: 2.1870e-08
# Epoch 44/50
# 264/264 [==============================] - ETA: 0s - loss: 7.1529e-04 - accuracy: 0.9999
# Epoch 44: val_accuracy did not improve from 0.98008
# Epoch 44: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.1529e-04 - accuracy: 0.9999 - val_loss: 0.0609 - val_accuracy: 0.9763 - lr: 2.1870e-08
# Epoch 45/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.4863e-04 - accuracy: 0.9999
# Epoch 45: val_accuracy did not improve from 0.98008
# Epoch 45: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.8814e-04 - accuracy: 0.9999 - val_loss: 0.0607 - val_accuracy: 0.9782 - lr: 2.1870e-08
# Epoch 46/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.9048e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.98008
# Epoch 46: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 7.8938e-04 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9763 - lr: 2.1870e-08
# Epoch 47/50
# 264/264 [==============================] - ETA: 0s - loss: 5.3492e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.98008
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.560999210591944e-09.
# Epoch 47: 13.39 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.3492e-04 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9782 - lr: 2.1870e-08
# Epoch 48/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.3117e-04 - accuracy: 0.9999
# Epoch 48: val_accuracy did not improve from 0.98008
# Epoch 48: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.3017e-04 - accuracy: 0.9999 - val_loss: 0.0609 - val_accuracy: 0.9772 - lr: 6.5610e-09
# Epoch 49/50
# 264/264 [==============================] - ETA: 0s - loss: 6.5089e-04 - accuracy: 0.9999
# Epoch 49: val_accuracy did not improve from 0.98008
# Epoch 49: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.5089e-04 - accuracy: 0.9999 - val_loss: 0.0613 - val_accuracy: 0.9782 - lr: 6.5610e-09
# Epoch 50/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.1592e-04 - accuracy: 0.9999
# Epoch 50: val_accuracy did not improve from 0.98008
# Epoch 50: 13.41 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.2165e-04 - accuracy: 0.9999 - val_loss: 0.0621 - val_accuracy: 0.9772 - lr: 6.5610e-09
# Total training time: 672.02 seconds
# 20/20 [==============================] - 1s 12ms/step
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0812 - accuracy: 0.9723
# Test Accuracy:  97.23
#               precision    recall  f1-score   support
#
#       glioma     0.9693    0.9930    0.9810       286
#   meningioma     0.9706    0.9296    0.9496       142
#    pituitary     0.9784    0.9731    0.9757       186
#
#     accuracy                         0.9723       614
#    macro avg     0.9727    0.9652    0.9688       614
# weighted avg     0.9723    0.9723    0.9722       614

# %%
labels = ['glioma', 'meningioma', 'pituitary']
data_path = '/root/autodl-tmp/dataset/figshare_MBTD/augmented'
image_size = 200
x_train, x_test, y_train, y_test = load_data(data_path, labels, image_size)


model = load_model()
adam = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint(filepath='model-test.h5',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 5, min_delta = 0.001,
                              mode='auto',verbose=1)
time_callback = TimeHistory()
history = model.fit(x_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=36,
                   callbacks=[tensorboard,checkpoint,reduce_lr, time_callback])


draw_curve(history)
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
loss,acc = model.evaluate(x_test,y_test,verbose = 1)
draw_matrix(labels, y_test_new, pred, acc)
# %reset -f
# Out:
# 100%|██████████| 3420/3420 [00:11<00:00, 308.40it/s]
# 100%|██████████| 286/286 [00:01<00:00, 254.80it/s]
# 100%|██████████| 3396/3396 [00:11<00:00, 300.36it/s]
# 100%|██████████| 142/142 [00:00<00:00, 258.75it/s]
# 100%|██████████| 3720/3720 [00:16<00:00, 230.67it/s]
# 100%|██████████| 186/186 [00:00<00:00, 194.11it/s]
# (614, 200, 200, 3)
# (10536, 200, 200, 3)
# (614, 3)
# (10536, 3)
# Epoch 1/50
#   5/264 [..............................] - ETA: 12s - loss: 1.6837 - accuracy: 0.4944WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0242s vs `on_train_batch_end` time: 0.0274s). Check your callbacks.
# 264/264 [==============================] - ETA: 0s - loss: 0.6978 - accuracy: 0.7246
# Epoch 1: val_accuracy improved from -inf to 0.34915, saving model to model-test.h5
# Epoch 1: 15.71 seconds
# 264/264 [==============================] - 16s 53ms/step - loss: 0.6978 - accuracy: 0.7246 - val_loss: 8.6209 - val_accuracy: 0.3491 - lr: 0.0010
# Epoch 2/50
# 264/264 [==============================] - ETA: 0s - loss: 0.4221 - accuracy: 0.8365
# Epoch 2: val_accuracy improved from 0.34915 to 0.61006, saving model to model-test.h5
# Epoch 2: 13.43 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.4221 - accuracy: 0.8365 - val_loss: 1.4675 - val_accuracy: 0.6101 - lr: 0.0010
# Epoch 3/50
# 264/264 [==============================] - ETA: 0s - loss: 0.3180 - accuracy: 0.8773
# Epoch 3: val_accuracy did not improve from 0.61006
# Epoch 3: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.3180 - accuracy: 0.8773 - val_loss: 1.8152 - val_accuracy: 0.6025 - lr: 0.0010
# Epoch 4/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.2471 - accuracy: 0.9061
# Epoch 4: val_accuracy did not improve from 0.61006
# Epoch 4: 13.27 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.2471 - accuracy: 0.9060 - val_loss: 1.8624 - val_accuracy: 0.5892 - lr: 0.0010
# Epoch 5/50
# 264/264 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9228
# Epoch 5: val_accuracy improved from 0.61006 to 0.68975, saving model to model-test.h5
# Epoch 5: 13.57 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.2005 - accuracy: 0.9228 - val_loss: 0.8894 - val_accuracy: 0.6898 - lr: 0.0010
# Epoch 6/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.1656 - accuracy: 0.9343
# Epoch 6: val_accuracy did not improve from 0.68975
# Epoch 6: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.1663 - accuracy: 0.9342 - val_loss: 6.8525 - val_accuracy: 0.4118 - lr: 0.0010
# Epoch 7/50
# 264/264 [==============================] - ETA: 0s - loss: 0.1440 - accuracy: 0.9460
# Epoch 7: val_accuracy improved from 0.68975 to 0.76376, saving model to model-test.h5
# Epoch 7: 13.48 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.1440 - accuracy: 0.9460 - val_loss: 0.7194 - val_accuracy: 0.7638 - lr: 0.0010
# Epoch 8/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9563
# Epoch 8: val_accuracy improved from 0.76376 to 0.91176, saving model to model-test.h5
# Epoch 8: 13.56 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.1177 - accuracy: 0.9563 - val_loss: 0.2133 - val_accuracy: 0.9118 - lr: 0.0010
# Epoch 9/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0995 - accuracy: 0.9643
# Epoch 9: val_accuracy did not improve from 0.91176
# Epoch 9: 13.26 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.1005 - accuracy: 0.9641 - val_loss: 0.4310 - val_accuracy: 0.8586 - lr: 0.0010
# Epoch 10/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0890 - accuracy: 0.9682
# Epoch 10: val_accuracy did not improve from 0.91176
# Epoch 10: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0891 - accuracy: 0.9682 - val_loss: 4.5812 - val_accuracy: 0.4810 - lr: 0.0010
# Epoch 11/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0834 - accuracy: 0.9691
# Epoch 11: val_accuracy did not improve from 0.91176
# Epoch 11: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0834 - accuracy: 0.9690 - val_loss: 6.6858 - val_accuracy: 0.3985 - lr: 0.0010
# Epoch 12/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9729
# Epoch 12: val_accuracy improved from 0.91176 to 0.91746, saving model to model-test.h5
# Epoch 12: 13.58 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0781 - accuracy: 0.9727 - val_loss: 0.1976 - val_accuracy: 0.9175 - lr: 0.0010
# Epoch 13/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9765
# Epoch 13: val_accuracy did not improve from 0.91746
# Epoch 13: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0682 - accuracy: 0.9765 - val_loss: 0.2675 - val_accuracy: 0.8909 - lr: 0.0010
# Epoch 14/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9823
# Epoch 14: val_accuracy did not improve from 0.91746
# Epoch 14: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0496 - accuracy: 0.9823 - val_loss: 1.5883 - val_accuracy: 0.6101 - lr: 0.0010
# Epoch 15/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0573 - accuracy: 0.9795
# Epoch 15: val_accuracy did not improve from 0.91746
# Epoch 15: 13.33 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0573 - accuracy: 0.9795 - val_loss: 0.4891 - val_accuracy: 0.8510 - lr: 0.0010
# Epoch 16/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9829
# Epoch 16: val_accuracy did not improve from 0.91746
# Epoch 16: 13.28 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0535 - accuracy: 0.9829 - val_loss: 0.2109 - val_accuracy: 0.9175 - lr: 0.0010
# Epoch 17/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9887
# Epoch 17: val_accuracy did not improve from 0.91746
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 17: 13.33 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0324 - accuracy: 0.9887 - val_loss: 0.2312 - val_accuracy: 0.9175 - lr: 0.0010
# Epoch 18/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9982
# Epoch 18: val_accuracy improved from 0.91746 to 0.96679, saving model to model-test.h5
# Epoch 18: 13.52 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0086 - accuracy: 0.9982 - val_loss: 0.0934 - val_accuracy: 0.9668 - lr: 3.0000e-04
# Epoch 19/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9991
# Epoch 19: val_accuracy improved from 0.96679 to 0.97913, saving model to model-test.h5
# Epoch 19: 13.53 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0058 - accuracy: 0.9991 - val_loss: 0.0609 - val_accuracy: 0.9791 - lr: 3.0000e-04
# Epoch 20/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9978
# Epoch 20: val_accuracy did not improve from 0.97913
# Epoch 20: 13.28 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0711 - val_accuracy: 0.9753 - lr: 3.0000e-04
# Epoch 21/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9986
# Epoch 21: val_accuracy did not improve from 0.97913
# Epoch 21: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.1841 - val_accuracy: 0.9459 - lr: 3.0000e-04
# Epoch 22/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9973
# Epoch 22: val_accuracy did not improve from 0.97913
# Epoch 22: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.1328 - val_accuracy: 0.9602 - lr: 3.0000e-04
# Epoch 23/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9994
# Epoch 23: val_accuracy did not improve from 0.97913
# Epoch 23: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0721 - val_accuracy: 0.9744 - lr: 3.0000e-04
# Epoch 24/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9982
# Epoch 24: val_accuracy did not improve from 0.97913
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 24: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.1542 - val_accuracy: 0.9583 - lr: 3.0000e-04
# Epoch 25/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0021 - accuracy: 0.9997
# Epoch 25: val_accuracy did not improve from 0.97913
# Epoch 25: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0537 - val_accuracy: 0.9791 - lr: 9.0000e-05
# Epoch 26/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9990
# Epoch 26: val_accuracy did not improve from 0.97913
# Epoch 26: 13.30 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0614 - val_accuracy: 0.9772 - lr: 9.0000e-05
# Epoch 27/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 27: val_accuracy improved from 0.97913 to 0.98102, saving model to model-test.h5
# Epoch 27: 13.56 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0482 - val_accuracy: 0.9810 - lr: 9.0000e-05
# Epoch 28/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9995
# Epoch 28: val_accuracy did not improve from 0.98102
# Epoch 28: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0519 - val_accuracy: 0.9810 - lr: 9.0000e-05
# Epoch 29/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9998
# Epoch 29: val_accuracy improved from 0.98102 to 0.98577, saving model to model-test.h5
# Epoch 29: 13.57 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0469 - val_accuracy: 0.9858 - lr: 9.0000e-05
# Epoch 30/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 30: val_accuracy did not improve from 0.98577
# Epoch 30: 13.21 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.2562 - val_accuracy: 0.9383 - lr: 9.0000e-05
# Epoch 31/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 31: val_accuracy did not improve from 0.98577
# Epoch 31: 13.30 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0533 - val_accuracy: 0.9820 - lr: 9.0000e-05
# Epoch 32/50
# 264/264 [==============================] - ETA: 0s - loss: 9.2911e-04 - accuracy: 0.9997
# Epoch 32: val_accuracy did not improve from 0.98577
# Epoch 32: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 9.2911e-04 - accuracy: 0.9997 - val_loss: 0.0721 - val_accuracy: 0.9753 - lr: 9.0000e-05
# Epoch 33/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9991
# Epoch 33: val_accuracy did not improve from 0.98577
# Epoch 33: 13.30 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0661 - val_accuracy: 0.9791 - lr: 9.0000e-05
# Epoch 34/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 34: val_accuracy did not improve from 0.98577
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 34: 13.33 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1126 - val_accuracy: 0.9687 - lr: 9.0000e-05
# Epoch 35/50
# 264/264 [==============================] - ETA: 0s - loss: 6.6778e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.98577
# Epoch 35: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.6778e-04 - accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 0.9810 - lr: 2.7000e-05
# Epoch 36/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.5492e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.98577
# Epoch 36: 13.25 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 5.5671e-04 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9829 - lr: 2.7000e-05
# Epoch 37/50
# 264/264 [==============================] - ETA: 0s - loss: 3.9558e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.98577
# Epoch 37: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 3.9558e-04 - accuracy: 1.0000 - val_loss: 0.0534 - val_accuracy: 0.9820 - lr: 2.7000e-05
# Epoch 38/50
# 263/264 [============================>.] - ETA: 0s - loss: 9.1562e-04 - accuracy: 0.9998
# Epoch 38: val_accuracy did not improve from 0.98577
# Epoch 38: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 9.1427e-04 - accuracy: 0.9998 - val_loss: 0.0504 - val_accuracy: 0.9839 - lr: 2.7000e-05
# Epoch 39/50
# 264/264 [==============================] - ETA: 0s - loss: 3.7305e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.98577
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 39: 13.18 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.7305e-04 - accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 0.9848 - lr: 2.7000e-05
# Epoch 40/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.9117e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.98577
# Epoch 40: 13.17 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 5.9055e-04 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 0.9848 - lr: 8.1000e-06
# Epoch 41/50
# 263/264 [============================>.] - ETA: 0s - loss: 3.1591e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.98577
# Epoch 41: 13.23 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.1564e-04 - accuracy: 1.0000 - val_loss: 0.0501 - val_accuracy: 0.9848 - lr: 8.1000e-06
# Epoch 42/50
# 264/264 [==============================] - ETA: 0s - loss: 5.5222e-04 - accuracy: 0.9999
# Epoch 42: val_accuracy did not improve from 0.98577
# Epoch 42: 13.23 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 5.5222e-04 - accuracy: 0.9999 - val_loss: 0.0488 - val_accuracy: 0.9848 - lr: 8.1000e-06
# Epoch 43/50
# 263/264 [============================>.] - ETA: 0s - loss: 3.3493e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy improved from 0.98577 to 0.98672, saving model to model-test.h5
# Epoch 43: 13.45 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 3.3574e-04 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9867 - lr: 8.1000e-06
# Epoch 44/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.0159e-04 - accuracy: 0.9999
# Epoch 44: val_accuracy did not improve from 0.98672
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 44: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.0074e-04 - accuracy: 0.9999 - val_loss: 0.0526 - val_accuracy: 0.9810 - lr: 8.1000e-06
# Epoch 45/50
# 264/264 [==============================] - ETA: 0s - loss: 3.5107e-04 - accuracy: 0.9999
# Epoch 45: val_accuracy did not improve from 0.98672
# Epoch 45: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 3.5107e-04 - accuracy: 0.9999 - val_loss: 0.0506 - val_accuracy: 0.9848 - lr: 2.4300e-06
# Epoch 46/50
# 263/264 [============================>.] - ETA: 0s - loss: 2.9380e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.98672
# Epoch 46: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 2.9344e-04 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 0.9839 - lr: 2.4300e-06
# Epoch 47/50
# 264/264 [==============================] - ETA: 0s - loss: 4.7435e-04 - accuracy: 0.9999
# Epoch 47: val_accuracy did not improve from 0.98672
# Epoch 47: 13.32 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 4.7435e-04 - accuracy: 0.9999 - val_loss: 0.0480 - val_accuracy: 0.9858 - lr: 2.4300e-06
# Epoch 48/50
# 264/264 [==============================] - ETA: 0s - loss: 4.0082e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.98672
# Epoch 48: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 4.0082e-04 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9848 - lr: 2.4300e-06
# Epoch 49/50
# 264/264 [==============================] - ETA: 0s - loss: 2.1021e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.98672
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# Epoch 49: 13.27 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.1021e-04 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 0.9858 - lr: 2.4300e-06
# Epoch 50/50
# 263/264 [============================>.] - ETA: 0s - loss: 2.0984e-04 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.98672
# Epoch 50: 13.26 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.0954e-04 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9867 - lr: 7.2900e-07
# Total training time: 670.24 seconds
# 20/20 [==============================] - 1s 13ms/step
# 20/20 [==============================] - 0s 15ms/step - loss: 0.1379 - accuracy: 0.9674
# Test Accuracy:  96.74
#               precision    recall  f1-score   support
#
#       glioma     0.9758    0.9860    0.9809       286
#   meningioma     0.9424    0.9225    0.9324       142
#    pituitary     0.9731    0.9731    0.9731       186
#
#     accuracy                         0.9674       614
#    macro avg     0.9638    0.9606    0.9621       614
# weighted avg     0.9673    0.9674    0.9673       614

# %%
labels = ['glioma', 'meningioma', 'pituitary']
data_path = '/root/autodl-tmp/dataset/figshare_MBTD/augmented'
image_size = 200
x_train, x_test, y_train, y_test = load_data(data_path, labels, image_size)


model = load_model()
adam = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint(filepath='model-test.h5',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 5, min_delta = 0.001,
                              mode='auto',verbose=1)
time_callback = TimeHistory()
history = model.fit(x_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=36,
                   callbacks=[tensorboard,checkpoint,reduce_lr, time_callback])


draw_curve(history)
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
loss,acc = model.evaluate(x_test,y_test,verbose = 1)
draw_matrix(labels, y_test_new, pred, acc)
# %reset -f
# Out:
# 100%|██████████| 3420/3420 [00:11<00:00, 308.53it/s]
# 100%|██████████| 286/286 [00:01<00:00, 257.52it/s]
# 100%|██████████| 3396/3396 [00:11<00:00, 300.06it/s]
# 100%|██████████| 142/142 [00:00<00:00, 260.16it/s]
# 100%|██████████| 3720/3720 [00:16<00:00, 229.86it/s]
# 100%|██████████| 186/186 [00:00<00:00, 194.83it/s]
# (614, 200, 200, 3)
# (10536, 200, 200, 3)
# (614, 3)
# (10536, 3)
# Epoch 1/50
#   5/264 [..............................] - ETA: 12s - loss: 1.3798 - accuracy: 0.4111WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0245s vs `on_train_batch_end` time: 0.0278s). Check your callbacks.
# 263/264 [============================>.] - ETA: 0s - loss: 0.6304 - accuracy: 0.7471
# Epoch 1: val_accuracy improved from -inf to 0.44687, saving model to model-test.h5
# Epoch 1: 15.74 seconds
# 264/264 [==============================] - 16s 53ms/step - loss: 0.6299 - accuracy: 0.7473 - val_loss: 4.4117 - val_accuracy: 0.4469 - lr: 1.0000e-04
# Epoch 2/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.3355 - accuracy: 0.8700
# Epoch 2: val_accuracy did not improve from 0.44687
# Epoch 2: 13.14 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.3364 - accuracy: 0.8699 - val_loss: 16.0853 - val_accuracy: 0.3330 - lr: 1.0000e-04
# Epoch 3/50
# 264/264 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9198
# Epoch 3: val_accuracy improved from 0.44687 to 0.65560, saving model to model-test.h5
# Epoch 3: 13.39 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.2144 - accuracy: 0.9198 - val_loss: 1.9009 - val_accuracy: 0.6556 - lr: 1.0000e-04
# Epoch 4/50
# 264/264 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9479
# Epoch 4: val_accuracy improved from 0.65560 to 0.85484, saving model to model-test.h5
# Epoch 4: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.1439 - accuracy: 0.9479 - val_loss: 0.4395 - val_accuracy: 0.8548 - lr: 1.0000e-04
# Epoch 5/50
# 264/264 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9597
# Epoch 5: val_accuracy did not improve from 0.85484
# Epoch 5: 13.09 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.1053 - accuracy: 0.9597 - val_loss: 0.9762 - val_accuracy: 0.7732 - lr: 1.0000e-04
# Epoch 6/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0730 - accuracy: 0.9748
# Epoch 6: val_accuracy did not improve from 0.85484
# Epoch 6: 13.18 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0730 - accuracy: 0.9747 - val_loss: 3.0623 - val_accuracy: 0.5958 - lr: 1.0000e-04
# Epoch 7/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9834
# Epoch 7: val_accuracy improved from 0.85484 to 0.86622, saving model to model-test.h5
# Epoch 7: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0506 - accuracy: 0.9834 - val_loss: 0.4549 - val_accuracy: 0.8662 - lr: 1.0000e-04
# Epoch 8/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9814
# Epoch 8: val_accuracy improved from 0.86622 to 0.87002, saving model to model-test.h5
# Epoch 8: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0527 - accuracy: 0.9812 - val_loss: 0.5200 - val_accuracy: 0.8700 - lr: 1.0000e-04
# Epoch 9/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0437 - accuracy: 0.9855
# Epoch 9: val_accuracy improved from 0.87002 to 0.87666, saving model to model-test.h5
# Epoch 9: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0437 - accuracy: 0.9856 - val_loss: 0.4270 - val_accuracy: 0.8767 - lr: 1.0000e-04
# Epoch 10/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0274 - accuracy: 0.9900
# Epoch 10: val_accuracy improved from 0.87666 to 0.91935, saving model to model-test.h5
# Epoch 10: 13.46 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0278 - accuracy: 0.9899 - val_loss: 0.2424 - val_accuracy: 0.9194 - lr: 1.0000e-04
# Epoch 11/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9895
# Epoch 11: val_accuracy did not improve from 0.91935
# Epoch 11: 13.21 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0325 - accuracy: 0.9896 - val_loss: 1.7129 - val_accuracy: 0.6850 - lr: 1.0000e-04
# Epoch 12/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9892
# Epoch 12: val_accuracy did not improve from 0.91935
# Epoch 12: 13.15 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0326 - accuracy: 0.9892 - val_loss: 0.3826 - val_accuracy: 0.9032 - lr: 1.0000e-04
# Epoch 13/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9940
# Epoch 13: val_accuracy did not improve from 0.91935
# Epoch 13: 13.15 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0179 - accuracy: 0.9940 - val_loss: 3.1659 - val_accuracy: 0.6556 - lr: 1.0000e-04
# Epoch 14/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9882
# Epoch 14: val_accuracy did not improve from 0.91935
# Epoch 14: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 0.5430 - val_accuracy: 0.8454 - lr: 1.0000e-04
# Epoch 15/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0118 - accuracy: 0.9963
# Epoch 15: val_accuracy improved from 0.91935 to 0.96584, saving model to model-test.h5
# Epoch 15: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0856 - val_accuracy: 0.9658 - lr: 1.0000e-04
# Epoch 16/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9929
# Epoch 16: val_accuracy did not improve from 0.96584
# Epoch 16: 13.15 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0197 - accuracy: 0.9929 - val_loss: 0.2086 - val_accuracy: 0.9250 - lr: 1.0000e-04
# Epoch 17/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9933
# Epoch 17: val_accuracy did not improve from 0.96584
# Epoch 17: 13.13 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.2269 - val_accuracy: 0.9383 - lr: 1.0000e-04
# Epoch 18/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9872
# Epoch 18: val_accuracy did not improve from 0.96584
# Epoch 18: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0339 - accuracy: 0.9872 - val_loss: 0.1828 - val_accuracy: 0.9307 - lr: 1.0000e-04
# Epoch 19/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9964
# Epoch 19: val_accuracy did not improve from 0.96584
# Epoch 19: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.4657 - val_accuracy: 0.8624 - lr: 1.0000e-04
# Epoch 20/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9937
# Epoch 20: val_accuracy did not improve from 0.96584
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# Epoch 20: 13.13 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.4006 - val_accuracy: 0.8975 - lr: 1.0000e-04
# Epoch 21/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9992
# Epoch 21: val_accuracy did not improve from 0.96584
# Epoch 21: 13.11 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.1948 - val_accuracy: 0.9431 - lr: 3.0000e-05
# Epoch 22/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 22: val_accuracy improved from 0.96584 to 0.98292, saving model to model-test.h5
# Epoch 22: 13.39 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0605 - val_accuracy: 0.9829 - lr: 3.0000e-05
# Epoch 23/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997
# Epoch 23: val_accuracy did not improve from 0.98292
# Epoch 23: 13.22 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1166 - val_accuracy: 0.9706 - lr: 3.0000e-05
# Epoch 24/50
# 264/264 [==============================] - ETA: 0s - loss: 9.9412e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy improved from 0.98292 to 0.98387, saving model to model-test.h5
# Epoch 24: 13.42 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 9.9412e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9839 - lr: 3.0000e-05
# Epoch 25/50
# 264/264 [==============================] - ETA: 0s - loss: 7.4960e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.98387
# Epoch 25: 13.22 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 7.4960e-04 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9829 - lr: 3.0000e-05
# Epoch 26/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997
# Epoch 26: val_accuracy improved from 0.98387 to 0.98767, saving model to model-test.h5
# Epoch 26: 13.45 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0572 - val_accuracy: 0.9877 - lr: 3.0000e-05
# Epoch 27/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 27: val_accuracy did not improve from 0.98767
# Epoch 27: 13.18 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1034 - val_accuracy: 0.9677 - lr: 3.0000e-05
# Epoch 28/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 28: val_accuracy did not improve from 0.98767
# Epoch 28: 13.11 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0859 - val_accuracy: 0.9782 - lr: 3.0000e-05
# Epoch 29/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.4355e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.98767 to 0.98861, saving model to model-test.h5
# Epoch 29: 13.29 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 5.4315e-04 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9886 - lr: 3.0000e-05
# Epoch 30/50
# 263/264 [============================>.] - ETA: 0s - loss: 3.3939e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.98861
# Epoch 30: 13.07 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.4070e-04 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9858 - lr: 3.0000e-05
# Epoch 31/50
# 263/264 [============================>.] - ETA: 0s - loss: 4.6111e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.98861
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# Epoch 31: 13.16 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 4.6067e-04 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 0.9839 - lr: 3.0000e-05
# Epoch 32/50
# 264/264 [==============================] - ETA: 0s - loss: 2.8026e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.98861
# Epoch 32: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.8026e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9848 - lr: 9.0000e-06
# Epoch 33/50
# 263/264 [============================>.] - ETA: 0s - loss: 2.6106e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.98861
# Epoch 33: 13.20 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.6074e-04 - accuracy: 1.0000 - val_loss: 0.0698 - val_accuracy: 0.9829 - lr: 9.0000e-06
# Epoch 34/50
# 264/264 [==============================] - ETA: 0s - loss: 3.0098e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.98861
# Epoch 34: 13.20 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.0098e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9867 - lr: 9.0000e-06
# Epoch 35/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.8895e-04 - accuracy: 0.9998
# Epoch 35: val_accuracy did not improve from 0.98861
# Epoch 35: 13.12 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 6.8808e-04 - accuracy: 0.9998 - val_loss: 0.0754 - val_accuracy: 0.9820 - lr: 9.0000e-06
# Epoch 36/50
# 263/264 [============================>.] - ETA: 0s - loss: 2.8178e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.98861
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# Epoch 36: 13.18 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.8144e-04 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 0.9848 - lr: 9.0000e-06
# Epoch 37/50
# 263/264 [============================>.] - ETA: 0s - loss: 1.4611e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.98861
# Epoch 37: 13.21 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 1.4592e-04 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9848 - lr: 2.7000e-06
# Epoch 38/50
# 264/264 [==============================] - ETA: 0s - loss: 2.9354e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.98861
# Epoch 38: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.9354e-04 - accuracy: 1.0000 - val_loss: 0.0556 - val_accuracy: 0.9877 - lr: 2.7000e-06
# Epoch 39/50
# 264/264 [==============================] - ETA: 0s - loss: 2.8023e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.98861
# Epoch 39: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.8023e-04 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9858 - lr: 2.7000e-06
# Epoch 40/50
# 264/264 [==============================] - ETA: 0s - loss: 2.0298e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.98861
# Epoch 40: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.0298e-04 - accuracy: 1.0000 - val_loss: 0.0588 - val_accuracy: 0.9848 - lr: 2.7000e-06
# Epoch 41/50
# 264/264 [==============================] - ETA: 0s - loss: 3.7585e-04 - accuracy: 0.9999
# Epoch 41: val_accuracy did not improve from 0.98861
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# Epoch 41: 13.22 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.7585e-04 - accuracy: 0.9999 - val_loss: 0.0603 - val_accuracy: 0.9839 - lr: 2.7000e-06
# Epoch 42/50
# 264/264 [==============================] - ETA: 0s - loss: 2.2472e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.98861
# Epoch 42: 13.19 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.2472e-04 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9839 - lr: 8.1000e-07
# Epoch 43/50
# 264/264 [==============================] - ETA: 0s - loss: 3.8021e-04 - accuracy: 0.9999
# Epoch 43: val_accuracy did not improve from 0.98861
# Epoch 43: 13.18 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.8021e-04 - accuracy: 0.9999 - val_loss: 0.0651 - val_accuracy: 0.9839 - lr: 8.1000e-07
# Epoch 44/50
# 263/264 [============================>.] - ETA: 0s - loss: 2.0002e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.98861
# Epoch 44: 13.16 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.0049e-04 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9839 - lr: 8.1000e-07
# Epoch 45/50
# 264/264 [==============================] - ETA: 0s - loss: 3.9891e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.98861
# Epoch 45: 13.20 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.9891e-04 - accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9839 - lr: 8.1000e-07
# Epoch 46/50
# 264/264 [==============================] - ETA: 0s - loss: 2.1456e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.98861
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# Epoch 46: 13.21 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 2.1456e-04 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9839 - lr: 8.1000e-07
# Epoch 47/50
# 263/264 [============================>.] - ETA: 0s - loss: 1.1955e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.98861
# Epoch 47: 13.22 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 1.1940e-04 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 0.9848 - lr: 2.4300e-07
# Epoch 48/50
# 264/264 [==============================] - ETA: 0s - loss: 1.7684e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.98861
# Epoch 48: 13.16 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 1.7684e-04 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 0.9848 - lr: 2.4300e-07
# Epoch 49/50
# 263/264 [============================>.] - ETA: 0s - loss: 1.2363e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.98861
# Epoch 49: 13.20 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 1.2432e-04 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 0.9848 - lr: 2.4300e-07
# Epoch 50/50
# 263/264 [============================>.] - ETA: 0s - loss: 1.3034e-04 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.98861
# Epoch 50: 13.10 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 1.3018e-04 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 0.9848 - lr: 2.4300e-07
# Total training time: 663.67 seconds
# 20/20 [==============================] - 1s 12ms/step
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0799 - accuracy: 0.9756
# Test Accuracy:  97.56
#               precision    recall  f1-score   support
#
#       glioma     0.9759    0.9930    0.9844       286
#   meningioma     0.9571    0.9437    0.9504       142
#    pituitary     0.9891    0.9731    0.9810       186
#
#     accuracy                         0.9756       614
#    macro avg     0.9741    0.9699    0.9719       614
# weighted avg     0.9756    0.9756    0.9755       614

# %%
labels = ['glioma', 'meningioma', 'pituitary']
data_path = '/root/autodl-tmp/dataset/figshare_MBTD/augmented'
image_size = 200
x_train, x_test, y_train, y_test = load_data(data_path, labels, image_size)


model = load_model()
adam = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint(filepath='model-test.h5',
                             monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 5, min_delta = 0.001,
                              mode='auto',verbose=1)
time_callback = TimeHistory()
history = model.fit(x_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=36,
                   callbacks=[tensorboard,checkpoint,reduce_lr, time_callback])


draw_curve(history)
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
loss,acc = model.evaluate(x_test,y_test,verbose = 1)
draw_matrix(labels, y_test_new, pred, acc)
# %reset -f
# Out:
# 100%|██████████| 3420/3420 [00:11<00:00, 305.31it/s]
# 100%|██████████| 286/286 [00:01<00:00, 249.79it/s]
# 100%|██████████| 3396/3396 [00:11<00:00, 294.28it/s]
# 100%|██████████| 142/142 [00:00<00:00, 257.43it/s]
# 100%|██████████| 3720/3720 [00:16<00:00, 226.92it/s]
# 100%|██████████| 186/186 [00:00<00:00, 193.07it/s]
# (614, 200, 200, 3)
# (10536, 200, 200, 3)
# (614, 3)
# (10536, 3)
# Epoch 1/50
#   6/264 [..............................] - ETA: 12s - loss: 1.2110 - accuracy: 0.5046WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0252s vs `on_train_batch_end` time: 0.0274s). Check your callbacks.
# 264/264 [==============================] - ETA: 0s - loss: 0.6379 - accuracy: 0.7426
# Epoch 1: val_accuracy improved from -inf to 0.33586, saving model to model-test.h5
# Epoch 1: 15.73 seconds
# 264/264 [==============================] - 16s 53ms/step - loss: 0.6379 - accuracy: 0.7426 - val_loss: 5.4318 - val_accuracy: 0.3359 - lr: 1.0000e-04
# Epoch 2/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.3226 - accuracy: 0.8765
# Epoch 2: val_accuracy improved from 0.33586 to 0.36243, saving model to model-test.h5
# Epoch 2: 13.47 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.3226 - accuracy: 0.8766 - val_loss: 5.2404 - val_accuracy: 0.3624 - lr: 1.0000e-04
# Epoch 3/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.2064 - accuracy: 0.9218
# Epoch 3: val_accuracy improved from 0.36243 to 0.63188, saving model to model-test.h5
# Epoch 3: 13.50 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.2061 - accuracy: 0.9220 - val_loss: 1.5648 - val_accuracy: 0.6319 - lr: 1.0000e-04
# Epoch 4/50
# 264/264 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9530
# Epoch 4: val_accuracy improved from 0.63188 to 0.91841, saving model to model-test.h5
# Epoch 4: 13.49 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.1288 - accuracy: 0.9530 - val_loss: 0.2404 - val_accuracy: 0.9184 - lr: 1.0000e-04
# Epoch 5/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0933 - accuracy: 0.9674
# Epoch 5: val_accuracy did not improve from 0.91841
# Epoch 5: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0933 - accuracy: 0.9673 - val_loss: 0.2059 - val_accuracy: 0.9137 - lr: 1.0000e-04
# Epoch 6/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9795
# Epoch 6: val_accuracy improved from 0.91841 to 0.95256, saving model to model-test.h5
# Epoch 6: 13.54 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0580 - accuracy: 0.9795 - val_loss: 0.1161 - val_accuracy: 0.9526 - lr: 1.0000e-04
# Epoch 7/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0538 - accuracy: 0.9820
# Epoch 7: val_accuracy did not improve from 0.95256
# Epoch 7: 13.30 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0537 - accuracy: 0.9821 - val_loss: 0.6615 - val_accuracy: 0.8738 - lr: 1.0000e-04
# Epoch 8/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9831
# Epoch 8: val_accuracy did not improve from 0.95256
# Epoch 8: 13.23 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0465 - accuracy: 0.9831 - val_loss: 0.8013 - val_accuracy: 0.8121 - lr: 1.0000e-04
# Epoch 9/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9882
# Epoch 9: val_accuracy did not improve from 0.95256
# Epoch 9: 13.28 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0337 - accuracy: 0.9882 - val_loss: 0.4180 - val_accuracy: 0.8672 - lr: 1.0000e-04
# Epoch 10/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0468 - accuracy: 0.9834
# Epoch 10: val_accuracy did not improve from 0.95256
# Epoch 10: 13.32 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0467 - accuracy: 0.9834 - val_loss: 0.1712 - val_accuracy: 0.9345 - lr: 1.0000e-04
# Epoch 11/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9895
# Epoch 11: val_accuracy did not improve from 0.95256
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# Epoch 11: 13.26 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0347 - accuracy: 0.9895 - val_loss: 0.2085 - val_accuracy: 0.9269 - lr: 1.0000e-04
# Epoch 12/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9979
# Epoch 12: val_accuracy improved from 0.95256 to 0.98008, saving model to model-test.h5
# Epoch 12: 13.50 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0549 - val_accuracy: 0.9801 - lr: 3.0000e-05
# Epoch 13/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9987
# Epoch 13: val_accuracy did not improve from 0.98008
# Epoch 13: 13.30 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.1076 - val_accuracy: 0.9583 - lr: 3.0000e-05
# Epoch 14/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9998
# Epoch 14: val_accuracy did not improve from 0.98008
# Epoch 14: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0557 - val_accuracy: 0.9744 - lr: 3.0000e-05
# Epoch 15/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9998
# Epoch 15: val_accuracy did not improve from 0.98008
# Epoch 15: 13.28 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0519 - val_accuracy: 0.9772 - lr: 3.0000e-05
# Epoch 16/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 16: val_accuracy did not improve from 0.98008
# Epoch 16: 13.30 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0751 - val_accuracy: 0.9734 - lr: 3.0000e-05
# Epoch 17/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 17: val_accuracy did not improve from 0.98008
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# Epoch 17: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0727 - val_accuracy: 0.9744 - lr: 3.0000e-05
# Epoch 18/50
# 264/264 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9998
# Epoch 18: val_accuracy improved from 0.98008 to 0.98197, saving model to model-test.h5
# Epoch 18: 13.59 seconds
# 264/264 [==============================] - 14s 51ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0503 - val_accuracy: 0.9820 - lr: 9.0000e-06
# Epoch 19/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9999
# Epoch 19: val_accuracy improved from 0.98197 to 0.98387, saving model to model-test.h5
# Epoch 19: 13.64 seconds
# 264/264 [==============================] - 14s 52ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.0529 - val_accuracy: 0.9839 - lr: 9.0000e-06
# Epoch 20/50
# 263/264 [============================>.] - ETA: 0s - loss: 9.7198e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.98387
# Epoch 20: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 9.7056e-04 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 0.9791 - lr: 9.0000e-06
# Epoch 21/50
# 263/264 [============================>.] - ETA: 0s - loss: 9.6560e-04 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.98387
# Epoch 21: 13.29 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 9.6430e-04 - accuracy: 1.0000 - val_loss: 0.0515 - val_accuracy: 0.9801 - lr: 9.0000e-06
# Epoch 22/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 22: val_accuracy did not improve from 0.98387
# Epoch 22: 13.24 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0480 - val_accuracy: 0.9839 - lr: 9.0000e-06
# Epoch 23/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.9067e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.98387
# Epoch 23: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.8978e-04 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9829 - lr: 9.0000e-06
# Epoch 24/50
# 264/264 [==============================] - ETA: 0s - loss: 9.2119e-04 - accuracy: 0.9999
# Epoch 24: val_accuracy did not improve from 0.98387
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# Epoch 24: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 9.2119e-04 - accuracy: 0.9999 - val_loss: 0.0499 - val_accuracy: 0.9829 - lr: 9.0000e-06
# Epoch 25/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.8535e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.98387
# Epoch 25: 13.28 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 7.8569e-04 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 0.9829 - lr: 2.7000e-06
# Epoch 26/50
# 263/264 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 0.9998
# Epoch 26: val_accuracy did not improve from 0.98387
# Epoch 26: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0509 - val_accuracy: 0.9820 - lr: 2.7000e-06
# Epoch 27/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.1924e-04 - accuracy: 0.9999
# Epoch 27: val_accuracy did not improve from 0.98387
# Epoch 27: 13.32 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 6.1875e-04 - accuracy: 0.9999 - val_loss: 0.0486 - val_accuracy: 0.9829 - lr: 2.7000e-06
# Epoch 28/50
# 264/264 [==============================] - ETA: 0s - loss: 6.9881e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.98387
# Epoch 28: 13.29 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 6.9881e-04 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9829 - lr: 2.7000e-06
# Epoch 29/50
# 264/264 [==============================] - ETA: 0s - loss: 5.1838e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.98387
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# Epoch 29: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.1838e-04 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9810 - lr: 2.7000e-06
# Epoch 30/50
# 264/264 [==============================] - ETA: 0s - loss: 6.5964e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.98387
# Epoch 30: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.5964e-04 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9810 - lr: 8.1000e-07
# Epoch 31/50
# 264/264 [==============================] - ETA: 0s - loss: 9.3073e-04 - accuracy: 0.9997
# Epoch 31: val_accuracy did not improve from 0.98387
# Epoch 31: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 9.3073e-04 - accuracy: 0.9997 - val_loss: 0.0470 - val_accuracy: 0.9810 - lr: 8.1000e-07
# Epoch 32/50
# 263/264 [============================>.] - ETA: 0s - loss: 3.6010e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.98387
# Epoch 32: 13.33 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.6165e-04 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9810 - lr: 8.1000e-07
# Epoch 33/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.8085e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.98387
# Epoch 33: 13.31 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 5.8026e-04 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9820 - lr: 8.1000e-07
# Epoch 34/50
# 263/264 [============================>.] - ETA: 0s - loss: 7.9422e-04 - accuracy: 0.9998
# Epoch 34: val_accuracy did not improve from 0.98387
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# Epoch 34: 13.32 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 7.9386e-04 - accuracy: 0.9998 - val_loss: 0.0468 - val_accuracy: 0.9810 - lr: 8.1000e-07
# Epoch 35/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.4611e-04 - accuracy: 0.9999
# Epoch 35: val_accuracy did not improve from 0.98387
# Epoch 35: 13.35 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.4534e-04 - accuracy: 0.9999 - val_loss: 0.0477 - val_accuracy: 0.9810 - lr: 2.4300e-07
# Epoch 36/50
# 264/264 [==============================] - ETA: 0s - loss: 5.1767e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.98387
# Epoch 36: 13.37 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.1767e-04 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9810 - lr: 2.4300e-07
# Epoch 37/50
# 264/264 [==============================] - ETA: 0s - loss: 5.4652e-04 - accuracy: 0.9999
# Epoch 37: val_accuracy did not improve from 0.98387
# Epoch 37: 13.26 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 5.4652e-04 - accuracy: 0.9999 - val_loss: 0.0486 - val_accuracy: 0.9810 - lr: 2.4300e-07
# Epoch 38/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.3323e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.98387
# Epoch 38: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.3282e-04 - accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 0.9810 - lr: 2.4300e-07
# Epoch 39/50
# 264/264 [==============================] - ETA: 0s - loss: 6.1718e-04 - accuracy: 0.9999
# Epoch 39: val_accuracy did not improve from 0.98387
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
# Epoch 39: 13.34 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.1718e-04 - accuracy: 0.9999 - val_loss: 0.0481 - val_accuracy: 0.9820 - lr: 2.4300e-07
# Epoch 40/50
# 264/264 [==============================] - ETA: 0s - loss: 4.7751e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.98387
# Epoch 40: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 4.7751e-04 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9810 - lr: 7.2900e-08
# Epoch 41/50
# 264/264 [==============================] - ETA: 0s - loss: 6.1258e-04 - accuracy: 0.9999
# Epoch 41: val_accuracy did not improve from 0.98387
# Epoch 41: 13.38 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.1258e-04 - accuracy: 0.9999 - val_loss: 0.0481 - val_accuracy: 0.9810 - lr: 7.2900e-08
# Epoch 42/50
# 263/264 [============================>.] - ETA: 0s - loss: 6.9925e-04 - accuracy: 0.9999
# Epoch 42: val_accuracy did not improve from 0.98387
# Epoch 42: 13.40 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.9915e-04 - accuracy: 0.9999 - val_loss: 0.0481 - val_accuracy: 0.9810 - lr: 7.2900e-08
# Epoch 43/50
# 264/264 [==============================] - ETA: 0s - loss: 6.4132e-04 - accuracy: 0.9999
# Epoch 43: val_accuracy did not improve from 0.98387
# Epoch 43: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.4132e-04 - accuracy: 0.9999 - val_loss: 0.0478 - val_accuracy: 0.9820 - lr: 7.2900e-08
# Epoch 44/50
# 264/264 [==============================] - ETA: 0s - loss: 8.8124e-04 - accuracy: 0.9998
# Epoch 44: val_accuracy did not improve from 0.98387
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 2.1869998079182552e-08.
# Epoch 44: 13.24 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 8.8124e-04 - accuracy: 0.9998 - val_loss: 0.0476 - val_accuracy: 0.9810 - lr: 7.2900e-08
# Epoch 45/50
# 264/264 [==============================] - ETA: 0s - loss: 3.0761e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.98387
# Epoch 45: 13.32 seconds
# 264/264 [==============================] - 13s 50ms/step - loss: 3.0761e-04 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9820 - lr: 2.1870e-08
# Epoch 46/50
# 264/264 [==============================] - ETA: 0s - loss: 7.8038e-04 - accuracy: 0.9999
# Epoch 46: val_accuracy did not improve from 0.98387
# Epoch 46: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 7.8038e-04 - accuracy: 0.9999 - val_loss: 0.0480 - val_accuracy: 0.9820 - lr: 2.1870e-08
# Epoch 47/50
# 264/264 [==============================] - ETA: 0s - loss: 4.1208e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.98387
# Epoch 47: 13.33 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 4.1208e-04 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 0.9810 - lr: 2.1870e-08
# Epoch 48/50
# 263/264 [============================>.] - ETA: 0s - loss: 5.4862e-04 - accuracy: 0.9999
# Epoch 48: val_accuracy did not improve from 0.98387
# Epoch 48: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 5.4784e-04 - accuracy: 0.9999 - val_loss: 0.0483 - val_accuracy: 0.9810 - lr: 2.1870e-08
# Epoch 49/50
# 264/264 [==============================] - ETA: 0s - loss: 8.0049e-04 - accuracy: 0.9999
# Epoch 49: val_accuracy did not improve from 0.98387
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.560999210591944e-09.
# Epoch 49: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 8.0049e-04 - accuracy: 0.9999 - val_loss: 0.0481 - val_accuracy: 0.9820 - lr: 2.1870e-08
# Epoch 50/50
# 264/264 [==============================] - ETA: 0s - loss: 6.0742e-04 - accuracy: 0.9999
# Epoch 50: val_accuracy did not improve from 0.98387
# Epoch 50: 13.36 seconds
# 264/264 [==============================] - 13s 51ms/step - loss: 6.0742e-04 - accuracy: 0.9999 - val_loss: 0.0481 - val_accuracy: 0.9810 - lr: 6.5610e-09
# Total training time: 670.11 seconds
# 20/20 [==============================] - 1s 13ms/step
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0801 - accuracy: 0.9739
# Test Accuracy:  97.39
#               precision    recall  f1-score   support
#
#       glioma     0.9727    0.9965    0.9845       286
#   meningioma     0.9638    0.9366    0.9500       142
#    pituitary     0.9836    0.9677    0.9756       186
#
#     accuracy                         0.9739       614
#    macro avg     0.9734    0.9670    0.9700       614
# weighted avg     0.9739    0.9739    0.9738       614
