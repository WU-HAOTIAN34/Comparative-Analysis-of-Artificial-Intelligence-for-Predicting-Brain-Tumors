# %%
from keras.models import load_model
import sys
sys.path.append("/root/autodl-tmp/Gradcam/")
from gradcam import sove_plots
from tensorflow.keras import backend as K
# Out:
# 2023-12-11 10:39:27.294325: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#activation_8
model = load_model('/root/autodl-tmp/DenseNet121/model-DenseNet121-2-09723.h5')
last_layer_name = 'conv5_block16_concat'
path = '/root/autodl-tmp/dataset/Br35H+SARTAJ+figshare/original/Testing/meningioma/Te-me_0054.jpg'
size = (200,200)
size2 = 6
sove_plots(path, size, model, last_layer_name, size2)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5eb01e3040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# 2
# ------------

# %%
#activation_8
model = load_model('/root/autodl-tmp/DenseNet121/model-DenseNet121-2-09723.h5')
last_layer_name = 'conv5_block16_concat'
path = '/root/autodl-tmp/dataset/Br35H+SARTAJ+figshare/original/Testing/meningioma/Te-meTr_0008.jpg'
size = (200,200)
size2 = 6
sove_plots(path, size, model, last_layer_name, size2)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5ec026de50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# 0
# ------------

# %%
model = load_model('/root/autodl-tmp/DenseNet121/model-DenseNet121-2-09723.h5')
last_layer_name = 'conv5_block16_concat'
path = '/root/autodl-tmp/dataset/Br35H+SARTAJ+figshare/original/Testing/meningioma/Te-me_0293.jpg'
size = (200,200)
size2 = 6
sove_plots(path, size, model, last_layer_name, size2)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 0
# ------------
