# %%
from keras.models import load_model
import sys
sys.path.append("/root/autodl-tmp/Gradcam/")
from gradcam import sove_plots
from tensorflow.keras import backend as K
# Out:
# 2024-04-17 17:47:36.243617: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#activation_8
model = load_model('/root/autodl-tmp/system/model/proposed.h5')
last_layer_name = 'multiply_2'
path = '/root/autodl-tmp/dataset/Br35H+SARTAJ+figshare/original/Testing/meningioma/Te-me_0036.jpg'
size = (200,200)
size2 = 12
sove_plots(path, size, model, last_layer_name, size2)
# Out:
# 1/1 [==============================] - 0s 276ms/step
# 1
# ------------

# %%
#activation_8
model = load_model('/root/autodl-tmp/system/model/proposed.h5')
last_layer_name = 'multiply_2'
path = '/root/autodl-tmp/dataset/Br35H+SARTAJ+figshare/original/Testing/meningioma/Te-meTr_0008.jpg'
size = (200,200)
size2 = 12
sove_plots(path, size, model, last_layer_name, size2)
# Out:
# 1/1 [==============================] - 0s 282ms/step
# 1
# ------------

# %%
#activation_8
model = load_model('/root/autodl-tmp/system/model/proposed.h5')
last_layer_name = 'multiply_2'
path = '/root/autodl-tmp/dataset/Br35H+SARTAJ+figshare/original/Testing/meningioma/Te-me_0022.jpg'
size = (200,200)
size2 = 12
sove_plots(path, size, model, last_layer_name, size2)
# Out:
# 1/1 [==============================] - 0s 276ms/step
# 2
# ------------

# %%
#activation_8
model = load_model('/root/autodl-tmp/system/model/proposed.h5')
last_layer_name = 'multiply_2'
path = '/root/autodl-tmp/dataset/Br35H+SARTAJ+figshare/original/Testing/meningioma/Te-me_0066.jpg'
size = (200,200)
size2 = 12
sove_plots(path, size, model, last_layer_name, size2)
# Out:
# 1/1 [==============================] - 0s 269ms/step
# 2
# ------------

# %%
#activation_8
model = load_model('/root/autodl-tmp/system/model/proposed.h5')
last_layer_name = 'multiply_2'
path = '/root/autodl-tmp/dataset/Br35H+SARTAJ+figshare/original/Testing/meningioma/Te-me_0057.jpg'
size = (200,200)
size2 = 12
sove_plots(path, size, model, last_layer_name, size2)
# Out:
# 1/1 [==============================] - 0s 267ms/step
# 2
# ------------
